# %% [markdown]
# # SEPTA Data Project
# #### William McKee
# #### December 2017
#
# SEPTA is a public agency responsible for the public transportation system in Philadelphia and its Pennsylvania suburbs.  SEPTA stands for Southeastern Pennsylvania Transportation Authority.
#
# This code analyzes the data set for SEPTA Bus and Rail lines downloaded from https://transitfeeds.com.  I downloaded the SEPTA Bus zip file and renamed gfts.zip to septa_bus_gfts.zip.  I downloaded the SEPTA Rail zip file and renamed gfts.zip to septa_rail_gfts.zip.

# %% [markdown]
# ## Data Set Conversion
#
# The code below checks the contents of both zip files, displays some zip file contents, and converts the files to csv format.

# %%
import zipfile
import csv
import os

def read_and_print_first_lines_from_zipped_file(zipfilename, limit):
    """
    Reads zip file and prints the first limit lines from each file contained in the zip file
    zipfilename = zip file name (such as 'example.zip')
    limit = number of lines to print in file
    """
    print()
    print("CONTENTS OF ZIP FILE " + zipfilename + ":")
    print()
    with zipfile.ZipFile(zipfilename, 'r') as z:
        file_name_list = sorted(z.namelist())
        for file in file_name_list:
            print(file)
            with z.open(file, 'r') as input_file:
                for line_number, line in enumerate(input_file):
                    if line_number > limit:
                        break
                    print(line)
            print()
    print()

# Loop through zip files
NUM_LINES = 5
ZIP_FILE_NAMES = ['septa_bus_gfts.zip', 'septa_rail_gfts.zip']
DIRECTORY_NAMES = []
for file in ZIP_FILE_NAMES:
    # Read the zip files and display some file contents
    read_and_print_first_lines_from_zipped_file(file, NUM_LINES)

    # Extract zip file contents
    directory_name = os.path.splitext(file)[0]
    DIRECTORY_NAMES.append(directory_name)
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(directory_name)

    # Convert txt files to csv files
    os.chdir(directory_name)
    for input_file in os.listdir('.'):
        with open(input_file, 'r') as in_file:
            stripped = (line.strip() for line in in_file)
            lines = (line.split(",") for line in stripped if line)
            output_file = os.path.splitext(input_file)[0] + ".csv"
            print("Convert " + input_file + " contents to " + output_file)
            with open(output_file, 'w', ) as out_file:
                writer = csv.writer(out_file, lineterminator = '\n')
                writer.writerows(lines)
            
    # Remove original text files
    for item in os.listdir('.'):
        if item.endswith(".txt"):
            os.remove(item)

    os.chdir('..')
# Out:
# CONTENTS OF ZIP FILE septa_bus_gfts.zip:
#
# agency.txt
# b'agency_name,agency_url,agency_timezone,agency_lang,agency_fare_url\r\n'
# b'SEPTA,http://www.septa.org,America/New_York,EN,http://www.septa.org/fares/transit/index.html'
#
# calendar.txt
# b'service_id,monday,tuesday,wednesday,thursday,friday,saturday,sunday,start_date,end_date\r\n'
# b'10,1,1,1,1,1,0,0,20170903,20180224\r\n'
# b'11,0,0,0,0,0,0,0,20170903,20180224\r\n'
# b'12,0,0,0,0,0,1,0,20170903,20180224\r\n'
# b'13,0,0,0,0,0,0,1,20170903,20180224\r\n'
# b'16,1,1,1,1,1,0,0,20170903,20180224\r\n'
#
# calendar_dates.txt
# b'service_id,date,exception_type\r\n'
# b'10,20170904,2\r\n'
# b'13,20170904,1\r\n'
# b'16,20170904,2\r\n'
# b'19,20170904,1\r\n'
# b'22,20170904,2\r\n'
#
# fare_attributes.txt
# b'fare_id,price,currency_type,payment_method,transfers,transfer_duration\r\n'
# b'1,2.50,USD,0,0,0\r\n'
# b'2,3.50,USD,0,1,3600\r\n'
# b'3,4.50,USD,0,2,3600\r\n'
# b'13,7.00,USD,0,0,0\r\n'
# b'14,8.00,USD,0,1,3600\r\n'
#
# fare_rules.txt
# b'fare_id,origin_id,destination_id\r\n'
# b'1,1,1\r\n'
# b'2,1,1\r\n'
# b'3,1,1\r\n'
# b'13,1,78\r\n'
# b'13,78,1\r\n'
#
# routes.txt
# b'route_id,route_short_name,route_long_name,route_type,route_color,route_text_color,route_url\r\n'
# b'1,1,Parx Casino to 54th-City,3,,,\r\n'
# b'10,10,13th-Market to 63rd-Malvern,0,66CC33,000000,\r\n'
# b'101,101,Media to 69th St TC,0,66CC33,000000,\r\n'
# b'102,102,Sharon Hill to 69th St TC,0,66CC33,000000,\r\n'
# b'103,103,Ardmore to 69th St TC,3,,,\r\n'
#
# shapes.txt
# b'shape_id,shape_pt_lat,shape_pt_lon,shape_pt_sequence\r\n'
# b'203286,39.96219,-75.259733,8\r\n'
# b'203286,39.962292,-75.259749,9\r\n'
# b'203286,39.962367,-75.259832,10\r\n'
# b'203286,39.962414,-75.259939,11\r\n'
# b'203286,39.962429,-75.26012,12\r\n'
#
# stop_times.txt
# b'trip_id,arrival_time,departure_time,stop_id,stop_sequence\r\n'
# b'914432,18:50:00,18:50:00,15497,1\r\n'
# b'914432,18:51:00,18:51:00,15319,2\r\n'
# b'914432,18:52:00,18:52:00,18597,3\r\n'
# b'914432,18:53:00,18:53:00,1938,4\r\n'
# b'914432,18:54:00,18:54:00,18598,5\r\n'
#
# stops.txt
# b'stop_id,stop_name,stop_lat,stop_lon,location_type,parent_station,zone_id,wheelchair_boarding\r\n'
# b'2,Ridge Av & Lincoln Dr  - FS,40.014986,-75.206826,,31032,1,0\r\n'
# b'4,Roosevelt Blvd & Broad St - FS,40.018128,-75.148887,,,1,\r\n'
# b'5,Roosevelt Blvd & 5th St,40.023465,-75.133487,,,1,\r\n'
# b'7,Roosevelt Blvd & Pratt St,40.028754,-75.089524,,,1,\r\n'
# b'8,Roosevelt Blvd & Cottman Av - FS,40.04461,-75.053657,,,1,0\r\n'
#
# transfers.txt
# b'from_stop_id,to_stop_id,transfer_type,min_transfer_time\r\n'
# b'1280,1280,3,\r\n'
#
# trips.txt
# b'route_id,service_id,trip_id,trip_headsign,block_id,direction_id,shape_id\r\n'
# b'1,10,035877,"Byberry Industrial Park",1006,0,205465\r\n'
# b'1,10,035878,"Decatur-Drummond",2152,0,205467\r\n'
# b'1,10,035879,"Byberry Industrial Park",1001,0,205465\r\n'
# b'1,10,035880,"Parx Casino",1009,0,205461\r\n'
# b'1,10,035881,"Parx Casino",1003,0,205461\r\n'
#
#
# Convert agency.txt contents to agency.csv
# Convert calendar.txt contents to calendar.csv
# Convert calendar_dates.txt contents to calendar_dates.csv
# Convert fare_attributes.txt contents to fare_attributes.csv
# Convert fare_rules.txt contents to fare_rules.csv
# Convert routes.txt contents to routes.csv
# Convert shapes.txt contents to shapes.csv
# Convert stops.txt contents to stops.csv
# Convert stop_times.txt contents to stop_times.csv
# Convert transfers.txt contents to transfers.csv
# Convert trips.txt contents to trips.csv
#
# CONTENTS OF ZIP FILE septa_rail_gfts.zip:
#
# agency.txt
# b'agency_id,agency_name,agency_url,agency_timezone,agency_lang,agency_email\n'
# b'SEPTA,SEPTA,http://www.septa.org,America/New_York,EN,noreply@septa.org\n'
#
# calendar.txt
# b'service_id, monday, tuesday, wednesday, thursday, friday, saturday, sunday, start_date, end_date\r\n'
# b'M1, 1, 1, 1, 1, 1, 0, 0, 20170910, 20171209\r\n'
# b'M2, 0, 0, 0, 0, 1, 0, 0, 20170910, 20171209\r\n'
# b'M3, 0, 0, 0, 0, 0, 1, 0, 20170910, 20171209\r\n'
# b'M4, 0, 0, 0, 0, 0, 0, 1, 20170910, 20171209\r\n'
# b'M5, 1, 1, 1, 1, 0, 0, 0, 20170910, 20171209\r\n'
#
# calendar_dates.txt
# b'service_id, date, exception_type\r\n'
# b'M1,20171123,2\r\n'
# b'M4,20171123,1'
#
# fare_attributes.txt
# b'fare_id, price, currency_type, payment_method, transfers, transfer_duration\r\n'
#
# fare_rules.txt
# b'fare_id, route_id, origin_id, destination_id, contains_id\r\n'
#
# routes.txt
# b'route_id,route_short_name,route_long_name,route_desc,agency_id,route_type,route_color,route_text_color,route_url\n'
# b'AIR,Airport Line,Airport Line,,SEPTA,2,91456C,FFFFFF,http://www.septa.org/schedules/rail/index.html\n'
# b'CHE,Chestnut Hill East Line,Chestnut Hill East Line,,SEPTA,2,94763C,FFFFFF,http://www.septa.org/schedules/rail/index.html\n'
# b'CHW,Chestnut Hill West Line,Chestnut Hill West Line,,SEPTA,2,00B4B2,FFFFFF,http://www.septa.org/schedules/rail/index.html\n'
# b'LAN,Lansdale/Doylestown Line,Lansdale/Doylestown Line,,SEPTA,2,775B49,FFFFFF,http://www.septa.org/schedules/rail/index.html\n'
# b'MED,Media/Elwyn Line,Media/Elwyn Line,,SEPTA,2,007CC8,FFFFFF,http://www.septa.org/schedules/rail/index.html\n'
#
# shapes.txt
# b'shape_id,shape_pt_lat,shape_pt_lon,shape_pt_sequence\n'
# b'228406,40.119678,-75.34621799999999,1\n'
# b'228406,40.119619,-75.34626400000001,2\n'
# b'228406,40.119574,-75.34629700000001,3\n'
# b'228406,40.11947,-75.346375,4\n'
# b'228406,40.119342,-75.346495,5\n'
#
# stop_times.txt
# b'trip_id,arrival_time,departure_time,stop_id,stop_sequence,pickup_type,drop_off_type\r\n'
# b'CYN_1054_V5_M,06:25:00,06:25:00,90001,1,0,0\r\n'
# b'CYN_1054_V5_M,06:26:00,06:27:00,90002,3,0,0\r\n'
# b'CYN_1054_V5_M,06:29:00,06:30:00,90003,5,0,0\r\n'
# b'CYN_1054_V5_M,06:42:00,06:42:00,90004,15,0,0\r\n'
# b'CYN_1054_V5_M,06:47:00,06:47:00,90005,19,0,0\r\n'
#
# stops.txt
# b'stop_id,stop_name,stop_desc,stop_lat,stop_lon,zone_id,wheelchair_boarding\r\n'
# b'90001,Cynwyd,Cynwyd Line,40.0066667,-75.2316667,2,1\r\n'
# b'90002,Bala,Cynwyd Line,40.0011111,-75.2277778,2,1\r\n'
# b'90003,Wynnefield Avenue,Cynwyd Line,39.99,-75.2255556,1,0\r\n'
# b'90004,30th Street Station,All Regional Rail Lines,39.9566667,-75.1816667,C,1\r\n'
# b'90005,Suburban Station,All Regional Rail Lines,39.9538889,-75.1677778,C,1\r\n'
#
# transfers.txt
# b'from_stop_id,to_stop_id,transfer_type\r\n'
# b'90004,90004,0\r\n'
# b'90005,90005,0\r\n'
# b'90006,90006,0'
#
# trips.txt
# b'route_id,service_id,trip_id,trip_headsign,block_id,trip_short_name,shape_id,direction_id\n'
# b'LAN,M3,LAN_512_V66_M,Doylestown,512,512,004538,0\n'
# b'TRE,M4,TRE_717_V77_M,Trenton,717,717,007701,1\n'
# b'PAO,M1,PAO_551_V55_M,Malvern,551,551,007505,1\n'
# b'MED,M3,MED_302_V66_M,Center City Philadelphia,302,302,301406,0\n'
# b'PAO,M1,PAO_560_V5_M,Center City Philadelphia,560,560,505004,0\n'
#
#
# Convert agency.txt contents to agency.csv
# Convert calendar.txt contents to calendar.csv
# Convert calendar_dates.txt contents to calendar_dates.csv
# Convert fare_attributes.txt contents to fare_attributes.csv
# Convert fare_rules.txt contents to fare_rules.csv
# Convert routes.txt contents to routes.csv
# Convert shapes.txt contents to shapes.csv
# Convert stops.txt contents to stops.csv
# Convert stop_times.txt contents to stop_times.csv
# Convert transfers.txt contents to transfers.csv
# Convert trips.txt contents to trips.csv

# %% [markdown]
# ## Data Set Basics
#
# We explore our CSV files for both bus and rail.  The groupings occur only on specific files which will reveal more useful information.

# %%
import pandas as pd

# Print sizes of CSV files
for directory in DIRECTORY_NAMES:
    os.chdir(directory)
    print("Looking at " + directory + " contents")
    print()
    for input_file in os.listdir('.'):
        print("Description of " + input_file + ":")
        data_set = pd.read_csv(input_file)
        print(data_set.shape)
        print()
    os.chdir('..')
# Out:
# Looking at septa_bus_gfts contents
#
# Description of agency.csv:
# (1, 5)
#
# Description of calendar.csv:
# (28, 10)
#
# Description of calendar_dates.csv:
# (168, 3)
#
# Description of fare_attributes.csv:
# (6, 6)
#
# Description of fare_rules.csv:
# (9, 3)
#
# Description of routes.csv:
# (139, 7)
#
# Description of shapes.csv:
# (570717, 4)
#
# Description of stops.csv:
# (13701, 8)
#
# Description of stop_times.csv:
# (3121225, 5)
#
# Description of transfers.csv:
# (1, 4)
#
# Description of trips.csv:
# (52000, 7)
#
# Looking at septa_rail_gfts contents
#
# Description of agency.csv:
# (1, 6)
#
# Description of calendar.csv:
# (5, 10)
#
# Description of calendar_dates.csv:
# (2, 3)
#
# Description of fare_attributes.csv:
# (0, 6)
#
# Description of fare_rules.csv:
# (0, 5)
#
# Description of routes.csv:
# (13, 9)
#
# Description of shapes.csv:
# (180235, 4)
#
# Description of stops.csv:
# (155, 7)
#
# Description of stop_times.csv:
# (25082, 7)
#
# Description of transfers.csv:
# (3, 3)
#
# Description of trips.csv:
# (1711, 8)

# %%
# Groupby could provide useful information for some files
GROUPBY_FILES_FIELDS = {'shapes.csv': 'shape_id', 
                        'trips.csv': 'route_id', 
                        'stop_times.csv': 'trip_id'}
for directory in DIRECTORY_NAMES:
    os.chdir(directory)
    print("Looking at " + directory + " groupby contents")
    print()
    for input_file in os.listdir('.'):
        if (input_file in GROUPBY_FILES_FIELDS.keys()):
            this_field = GROUPBY_FILES_FIELDS[input_file]
            print("Description of " + input_file + " Groupings:")
            data_set = pd.read_csv(input_file)
            data_set_distinct = data_set.groupby(this_field)[this_field].count()
            print(data_set_distinct)
            print()
    os.chdir('..')
# Out:
# Looking at septa_bus_gfts groupby contents
#
# Description of shapes.csv Groupings:
# shape_id
# 203286     296
# 203287     296
# 203288     280
# 203290     195
# 203291     273
# 203292     188
# 203293     289
# 203305     211
# 203307     189
# 203308     204
# 203310     182
# 203311      95
# 203312     288
# 203313      84
# 203314      84
# 203315     338
# 203316     790
# 203317     896
# 203318     790
# 203319     900
# 203320     872
# 203322     305
# 203323     372
# 203324     387
# 203325     790
# 203326     306
# 203327     321
# 203329     381
# 203330     361
# 203332     814
#           ...
# 206251     328
# 206287     253
# 206288     276
# 206289     170
# 206290     249
# 206291     249
# 206293     235
# 206294     257
# 206305     251
# 206308     403
# 206309     578
# 206310     484
# 206311    1180
# 206312     496
# 206313    1086
# 206314     597
# 206315     409
# 206317     304
# 206318     381
# 206319    1001
# 206320     990
# 206321     408
# 206322     370
# 206323    1079
# 206324     457
# 206325     366
# 206326     884
# 206327    1337
# 206329    1419
# 208290     187
# Name: shape_id, Length: 1147, dtype: int64
#
# Description of stop_times.csv Groupings:
# trip_id
# 652       49
# 653       49
# 654       49
# 655       49
# 656       49
# 657       49
# 658       49
# 659       49
# 660       49
# 661       49
# 662       49
# 663       49
# 664       49
# 665       49
# 666       49
# 667       49
# 668       49
# 669       49
# 670       49
# 671       49
# 672       49
# 673       49
# 674       49
# 675       49
# 676       49
# 677       49
# 678       49
# 679       49
# 680       49
# 681       49
#           ..
# 995195    45
# 995196    45
# 995197    45
# 995198    45
# 995199    45
# 995200    45
# 995201    45
# 995202    45
# 995203    45
# 995204    45
# 995205    45
# 995206    45
# 995207    45
# 995208    45
# 995209    45
# 995210    45
# 995211    45
# 995212    45
# 995213    45
# 995214    45
# 995215    45
# 995216    45
# 995217    45
# 995218    45
# 995219    45
# 995220    45
# 995221    45
# 995222    45
# 995223    45
# 995224    45
# Name: trip_id, Length: 52000, dtype: int64
#
# Description of trips.csv Groupings:
# route_id
# 1           132
# 10          794
# 101         400
# 102         380
# 103         201
# 104         312
# 105         174
# 106         100
# 107         118
# 108         520
# 109         406
# 11          720
# 110         227
# 111         205
# 112         163
# 113         521
# 114         193
# 115         166
# 117         236
# 118          82
# 119         132
# 12          390
# 120          90
# 123         195
# 124         236
# 125         229
# 126         132
# 127          69
# 128          58
# 129         117
#            ...
# 80           18
# 84          241
# 88          294
# 89          224
# 9           386
# 90           97
# 91            6
# 92           70
# 93          168
# 94           95
# 95          104
# 96          198
# 97          144
# 98          176
# 99          212
# BLVDDIR     600
# BSL        1746
# BSO          98
# G           694
# H           400
# J           256
# K           524
# L           704
# LUCYGO      132
# LUCYGR      114
# MFL        1226
# MFO          80
# NHSL        576
# R           664
# XH          394
# Name: route_id, Length: 139, dtype: int64
#
# Looking at septa_rail_gfts groupby contents
#
# Description of shapes.csv Groupings:
# shape_id
# 1005       837
# 4226      2210
# 4227      2345
# 4228      2380
# 4327      3303
# 4417      2527
# 4531      3166
# 4534      3364
# 4538      3987
# 4720      1445
# 4815      1468
# 5001       837
# 5201       740
# 5203       517
# 5501      1836
# 5701      2540
# 5801      1454
# 6501      1907
# 6505      1795
# 6506      1685
# 7201       770
# 7203       547
# 7204       335
# 7205       305
# 7301      1802
# 7401      1283
# 7501      2122
# 7505      2010
# 7506      1900
# 7516      1310
#           ...
# 411004    1578
# 411007    1154
# 417004    2527
# 417007    2103
# 501004    1698
# 501006    1907
# 501007    2122
# 501008    2122
# 505004    1586
# 505005    1724
# 505006    1795
# 505007    2010
# 505008    2010
# 506004    1476
# 514007    1456
# 516004     886
# 516007    1310
# 531007    2742
# 533007    2906
# 534007    2940
# 538004    3987
# 538007    3563
# 701004    2402
# 701005    2540
# 701007    2825
# 720004    1445
# 720007    1021
# 801004    1316
# 801007    1739
# 815007    1044
# Name: shape_id, Length: 98, dtype: int64
#
# Description of stop_times.csv Groupings:
# trip_id
# AIR_3459_V5_M     10
# AIR_401_V1_M      10
# AIR_401_V66_M     10
# AIR_401_V77_M     10
# AIR_403_V1_M      10
# AIR_403_V66_M     10
# AIR_403_V77_M     10
# AIR_404_V5_M       6
# AIR_404_V66_M      6
# AIR_404_V77_M      6
# AIR_405_V1_M      10
# AIR_405_V66_M     10
# AIR_405_V77_M     10
# AIR_407_V1_M      10
# AIR_407_V66_M     10
# AIR_407_V77_M     10
# AIR_408_V5_M       6
# AIR_408_V66_M      6
# AIR_408_V77_M      6
# AIR_409_V5_M      10
# AIR_409_V66_M     10
# AIR_409_V77_M     10
# AIR_412_V5_M       6
# AIR_412_V66_M      6
# AIR_412_V77_M      6
# AIR_413_V66_M     10
# AIR_413_V77_M     10
# AIR_414_V5_M       6
# AIR_416_V5_M       6
# AIR_416_V66_M      6
#                   ..
# WTR_393_V5_M      19
# WTR_394_V5_M      20
# WTR_395_V5_M      16
# WTR_396_V5_M      20
# WTR_398_V5_M      20
# WTR_4376_V5_M     17
# WTR_6300_V55_M    19
# WTR_6301_V55_M    18
# WTR_6302_V55_M    19
# WTR_6303_V55_M    19
# WTR_6304_V55_M    19
# WTR_6305_V55_M    19
# WTR_6306_V55_M    19
# WTR_6307_V55_M    19
# WTR_6308_V55_M    19
# WTR_6309_V55_M    19
# WTR_6310_V5_M     19
# WTR_6311_V55_M    19
# WTR_6312_V5_M     14
# WTR_6313_V55_M    19
# WTR_6321_V5_M     14
# WTR_6322_V5_M     22
# WTR_6325_V5_M     14
# WTR_6327_V55_M    18
# WTR_6358_V5_M     19
# WTR_6368_V5_M     19
# WTR_6370_V55_M    21
# WTR_6374_V5_M     14
# WTR_6378_V5_M     14
# WTR_7390_V5_M     19
# Name: trip_id, Length: 1711, dtype: int64
#
# Description of trips.csv Groupings:
# route_id
# AIR    234
# CHE    120
# CHW    105
# CYN     21
# FOX     97
# LAN    145
# MED    127
# NOR    128
# PAO    187
# TRE    139
# WAR    164
# WIL    118
# WTR    126
# Name: route_id, dtype: int64

# %% [markdown]
# ## One Train Route
#
# Here, I will get the data associated with the Trenton Rail Line for train #734.

# %%
# Train directory
os.chdir(DIRECTORY_NAMES[1])

# List route information
routes_data_set = pd.read_csv('routes.csv')

print("Routes Data Set")
print(routes_data_set[['route_id', 'route_short_name', 'route_color']])
# Out:
# Routes Data Set
#    route_id          route_short_name route_color
# 0       AIR              Airport Line      91456C
# 1       CHE   Chestnut Hill East Line      94763C
# 2       CHW   Chestnut Hill West Line      00B4B2
# 3       LAN  Lansdale/Doylestown Line      775B49
# 4       MED          Media/Elwyn Line      007CC8
# 5       FOX            Fox Chase Line      FF823D
# 6       NOR  Manayunk/Norristown Line      EE4C69
# 7       PAO      Paoli/Thorndale Line      20825C
# 8       CYN               Cynwyd Line      6F549E
# 9       TRE              Trenton Line      F683C9
# 10      WAR           Warminster Line      F7AF42
# 11      WIL    Wilmington/Newark Line      8AD16B
# 12      WTR         West Trenton Line      5D5EBC

# %%
# Find trips associated with the TRE line
trips_data_set = pd.read_csv('trips.csv')
trips_data_set_tre = trips_data_set.loc[trips_data_set['route_id'] == 'TRE']

print("Trips Data Set for Trenton")
print(trips_data_set_tre[['trip_id', 'service_id', 'trip_headsign', 'block_id', 'shape_id']])
# Out:
# Trips Data Set for Trenton
#              trip_id service_id             trip_headsign  block_id  shape_id
# 1      TRE_717_V77_M         M4                   Trenton       717      7701
# 5      TRE_723_V77_M         M4                   Trenton       723      7701
# 11      TRE_773_V5_M         M1                   Trenton       773      7701
# 25      TRE_705_V5_M         M1                   Trenton       705      7701
# 74     TRE_9741_V5_M         M1                   Trenton      9741      7701
# 78     TRE_711_V66_M         M3                   Trenton       711      7701
# 81     TRE_7218_V5_M         M1  Center City Philadelphia      7218    701007
# 85     TRE_708_V77_M         M4  Center City Philadelphia       708    701004
# 104    TRE_1766_V5_M         M1  Center City Philadelphia      1766    701005
# 123     TRE_774_V5_M         M1  Center City Philadelphia       774    701004
# 127    TRE_722_V77_M         M4  Center City Philadelphia       722    701004
# 128    TRE_7406_V5_M         M1  Center City Philadelphia      7406    701004
# 130    TRE_9737_V5_M         M1                   Trenton      9737      7701
# 149    TRE_7250_V5_M         M1  Center City Philadelphia      7250    701004
# 160    TRE_706_V77_M         M4  Center City Philadelphia       706    701004
# 162     TRE_757_V5_M         M1                   Trenton       757      7701
# 163    TRE_732_V77_M         M4  Center City Philadelphia       732    701004
# 174    TRE_705_V66_M         M3                   Trenton       705      7701
# 176    TRE_9745_V5_M         M1                   Trenton      9745      7701
# 185   TRE_9736_V66_M         M3  Center City Philadelphia      9736    701007
# 201    TRE_9730_V5_M         M1  Center City Philadelphia      9730    701007
# 211    TRE_720_V66_M         M3  Center City Philadelphia       720    701004
# 225    TRE_714_V66_M         M3  Center City Philadelphia       714    701004
# 237    TRE_9728_V5_M         M1  Center City Philadelphia      9728    701007
# 278     TRE_738_V5_M         M1  Center City Philadelphia       738    701004
# 289    TRE_733_V77_M         M4                   Trenton       733      7701
# 290     TRE_736_V5_M         M1  Center City Philadelphia       736    701004
# 300    TRE_3755_V5_M         M1                   Trenton      3755      7701
# 309    TRE_7220_V5_M         M1  Center City Philadelphia      7220    701007
# 310    TRE_730_V77_M         M4  Center City Philadelphia       730    701004
# ...              ...        ...                       ...       ...       ...
# 1258   TRE_7390_V5_M         M1  Center City Philadelphia      7390    701004
# 1264   TRE_9747_V5_M         M1                   Trenton      9747      7701
# 1267   TRE_1701_V5_M         M1                   Trenton      1701      5701
# 1286  TRE_9700_V66_M         M3  Center City Philadelphia      9700    701007
# 1294    TRE_759_V5_M         M1                   Trenton       759      7701
# 1315    TRE_740_V5_M         M1  Center City Philadelphia       740    701004
# 1316    TRE_758_V5_M         M1  Center City Philadelphia       758    701004
# 1338  TRE_8721_V55_M         M1                   Trenton      8721      7701
# 1350  TRE_9701_V66_M         M3                   Trenton      9701      7701
# 1365   TRE_735_V77_M         M4                   Trenton       735      7701
# 1372  TRE_7534_V44_M         M1  Center City Philadelphia      7534    701004
# 1379   TRE_724_V77_M         M4  Center City Philadelphia       724    701004
# 1411    TRE_733_V5_M         M1                   Trenton       733      7701
# 1423  TRE_8775_V55_M         M1                   Trenton      8775      7701
# 1445   TRE_734_V77_M         M4  Center City Philadelphia       734    701004
# 1451    TRE_765_V5_M         M1                   Trenton       765      7701
# 1472   TRE_9784_V5_M         M1  Center City Philadelphia      9784    701007
# 1503   TRE_706_V66_M         M3  Center City Philadelphia       706    701004
# 1530   TRE_9739_V5_M         M1                   Trenton      9739      7701
# 1544   TRE_703_V66_M         M3                   Trenton       703      7701
# 1559  TRE_9738_V66_M         M3  Center City Philadelphia      9738    701007
# 1565   TRE_9781_V5_M         M1                   Trenton      9781      7701
# 1577    TRE_768_V5_M         M1  Center City Philadelphia       768    701004
# 1630   TRE_9703_V5_M         M1                   Trenton      9703      7701
# 1632   TRE_721_V77_M         M4                   Trenton       721      7701
# 1635   TRE_727_V66_M         M3                   Trenton       727      7701
# 1641    TRE_731_V5_M         M1                   Trenton       731      7701
# 1664   TRE_723_V66_M         M3                   Trenton       723      7701
# 1688   TRE_714_V77_M         M4  Center City Philadelphia       714    701004
# 1690   TRE_739_V66_M         M3                   Trenton       739      7701
#
# [139 rows x 5 columns]

# %%
# Look for rows associated with train #734 on the Trenton Line
trips_data_set_tre_734 = trips_data_set_tre.loc[trips_data_set['block_id'] == 734]

print("Trips Data Set for Trenton Train #734")
print(trips_data_set_tre_734[['trip_id', 'service_id', 'trip_headsign', 'block_id', 'shape_id']])
# Out:
# Trips Data Set for Trenton Train #734
#             trip_id service_id             trip_headsign  block_id  shape_id
# 1009  TRE_734_V66_M         M3  Center City Philadelphia       734    701004
# 1152   TRE_734_V5_M         M1  Center City Philadelphia       734    701004
# 1445  TRE_734_V77_M         M4  Center City Philadelphia       734    701004

# %%
# Obtain the schedule for train #734 on the Trenton Line
trip_ids = trips_data_set_tre_734['trip_id'].tolist()

stop_times_data_set = pd.read_csv('stop_times.csv')
stop_times_data_set_tre_734 = stop_times_data_set[stop_times_data_set['trip_id'].isin(trip_ids)]

print("Stop Times Data Set for Trenton Train #734")
print(stop_times_data_set_tre_734[['trip_id', 'arrival_time', 'stop_id', 'stop_sequence']])
# Out:
# Stop Times Data Set for Trenton Train #734
#              trip_id arrival_time  stop_id  stop_sequence
# 19721   TRE_734_V5_M     10:43:00    90701              1
# 19722   TRE_734_V5_M     10:50:00    90702              4
# 19723   TRE_734_V5_M     10:54:00    90703              6
# 19724   TRE_734_V5_M     10:58:00    90704              7
# 19725   TRE_734_V5_M     11:00:00    90705              8
# 19726   TRE_734_V5_M     11:02:00    90706              9
# 19727   TRE_734_V5_M     11:05:00    90707             11
# 19728   TRE_734_V5_M     11:09:00    90708             12
# 19729   TRE_734_V5_M     11:10:00    90709             13
# 19730   TRE_734_V5_M     11:13:00    90710             15
# 19731   TRE_734_V5_M     11:20:00    90711             17
# 19746   TRE_734_V5_M     11:33:00    90004             27
# 19747  TRE_734_V66_M     22:59:00    90701              1
# 19748  TRE_734_V66_M     23:07:00    90702              4
# 19749  TRE_734_V66_M     23:10:00    90703              6
# 19750  TRE_734_V66_M     23:14:00    90704              7
# 19751  TRE_734_V66_M     23:16:00    90705              8
# 19752  TRE_734_V66_M     23:18:00    90706              9
# 19753  TRE_734_V66_M     23:21:00    90707             11
# 19754  TRE_734_V66_M     23:25:00    90708             12
# 19755  TRE_734_V66_M     23:27:00    90709             13
# 19756  TRE_734_V66_M     23:30:00    90710             15
# 19757  TRE_734_V66_M     23:37:00    90711             17
# 19772  TRE_734_V66_M     23:47:00    90004             27
# 19773  TRE_734_V77_M     22:59:00    90701              1
# 19774  TRE_734_V77_M     23:07:00    90702              4
# 19775  TRE_734_V77_M     23:10:00    90703              6
# 19776  TRE_734_V77_M     23:14:00    90704              7
# 19777  TRE_734_V77_M     23:16:00    90705              8
# 19778  TRE_734_V77_M     23:18:00    90706              9
# 19779  TRE_734_V77_M     23:21:00    90707             11
# 19780  TRE_734_V77_M     23:25:00    90708             12
# 19781  TRE_734_V77_M     23:27:00    90709             13
# 19782  TRE_734_V77_M     23:30:00    90710             15
# 19783  TRE_734_V77_M     23:37:00    90711             17
# 19798  TRE_734_V77_M     23:47:00    90004             27

# %%
# Focus on trip V5
stop_times_data_set_tre_734_v5 = stop_times_data_set_tre_734[stop_times_data_set_tre_734['trip_id'] == 'TRE_734_V5_M']

# Obtain the list of stops for train #734 for Trenton Line
stop_ids = stop_times_data_set_tre_734_v5['stop_id'].tolist()
print(stop_ids)

stops_data_set = pd.read_csv('stops.csv')
stops_data_set_tre_734_v5 = stops_data_set[stops_data_set['stop_id'].isin(stop_ids)]

print("Stops Data Set for Trenton Train #734 V5")
print(stops_data_set_tre_734_v5[['stop_id', 'stop_name', 'stop_lat', 'stop_lon', 'zone_id']])
# Out:
# [90701, 90702, 90703, 90704, 90705, 90706, 90707, 90708, 90709, 90710, 90711, 90004]
# Stops Data Set for Trenton Train #734 V5
#      stop_id                  stop_name   stop_lat   stop_lon zone_id
# 3      90004        30th Street Station  39.956667 -75.181667       C
# 120    90701                    Trenton  40.217778 -74.755000      NJ
# 121    90702        Levittown-Tullytown  40.140278 -74.816944       4
# 122    90703                    Bristol  40.104722 -74.854722       4
# 123    90704                    Croydon  40.093611 -74.906667       3
# 124    90705                  Eddington  40.083056 -74.933611       3
# 125    90706          Cornwells Heights  40.071667 -74.952222       3
# 126    90707                 Torresdale  40.054444 -74.984444       3
# 127    90708             Holmesburg Jct  40.032778 -75.023611       2
# 128    90709                     Tacony  40.023333 -75.038889       2
# 129    90710                 Bridesburg  40.010556 -75.069722       2
# 130    90711  North Philadelphia Amtrak  39.997222 -75.155000       1
